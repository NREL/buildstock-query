# %%
from buildstock_query import UpgradesAnalyzer

# %%
ua = UpgradesAnalyzer("project-file-example.yml", "buildstock.csv")

# %%
report_df = ua.get_report()
report_df
# Out:
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 1
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 2
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 3
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 4
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 5
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 6
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 7
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 8
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 9
# INFO:buildstock_query.upgrades_analyzer:Analyzing upgrade 10
#      upgrade                                       upgrade_name  option_num  \
# 0          1                                    Basic Enclosure           1
# 1          1                                    Basic Enclosure           2
# 2          1                                    Basic Enclosure           3
# 3          1                                    Basic Enclosure           4
# 4          1                                    Basic Enclosure           5
# ..       ...                                                ...         ...
# 183       10  Highly-efficient all-electric homes + enhanced...          23
# 184       10  Highly-efficient all-electric homes + enhanced...          24
# 185       10  Highly-efficient all-electric homes + enhanced...          25
# 186       10  Highly-efficient all-electric homes + enhanced...          26
# 187       10  Highly-efficient all-electric homes + enhanced...          -1
#
#                                                 option  applicable_to  \
# 0                              Insulation Ceiling|R-30           1300
# 1                              Insulation Ceiling|R-49         140920
# 2                              Insulation Ceiling|R-60         213080
# 3                           Infiltration Reduction|30%         366032
# 4                               Ducts|10% Leakage, R-8          49564
# ..                                                 ...            ...
# 183  Clothes Dryer|Electric, Premium, Heat Pump, Ve...         114895
# 184       Cooking Range|Electric, Induction, 80% Usage         136060
# 185      Cooking Range|Electric, Induction, 100% Usage         271763
# 186      Cooking Range|Electric, Induction, 120% Usage         136286
# 187                                                All         550000
#
#      applicable_percent                               applicable_buildings
# 0                   0.2  {363615, 423262, 358591, 464049, 193333, 35915...
# 1                  25.6  {312604, 302509, 533613, 496614, 83247, 202682...
# 2                  38.7  {276979, 292500, 209169, 487894, 539328, 22825...
# 3                  66.6  {443012, 533613, 487894, 211350, 25089, 307641...
# 4                   9.0  {179783, 541118, 14824, 195371, 149495, 415885...
# ..                  ...                                                ...
# 183                20.9  {312604, 27403, 355501, 287478, 134862, 182340...
# 184                24.7  {443012, 152000, 496614, 83247, 202682, 355709...
# 185                49.4  {276979, 533613, 292500, 209169, 487894, 53932...
# 186                24.8  {312604, 27403, 355501, 287478, 134862, 182340...
# 187               100.0  {443012, 533613, 487894, 211350, 404097, 25089...
#
# [188 rows x 7 columns]

# %%
report_df.drop(columns=['applicable_buildings']).to_csv("Upgrades_report.csv")

# %%
ua.save_detailed_report_all("detailed_report.txt")
# Out:
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 1
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 2
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 3
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 4
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 5
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 6
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 7
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 8
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 9
# INFO:buildstock_query.upgrades_analyzer:Getting report for upgrade 10
# Saving report to detailed_report.txt
