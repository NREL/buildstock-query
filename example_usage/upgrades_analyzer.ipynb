# %%
from buildstock_query import UpgradesAnalyzer

# %%
yaml_file = "project-file-example.yml"
buildstock_file = "buildstock.csv"
ua = UpgradesAnalyzer(yaml_file, buildstock_file)

# %%
report_df = ua.get_report()
report_df
# Out:
# INFO:buildstock_query.tools.upgrades_analyzer:Analyzing upgrade 1
# INFO:buildstock_query.tools.upgrades_analyzer:Analyzing upgrade 2
# INFO:buildstock_query.tools.upgrades_analyzer:Analyzing upgrade 3
# INFO:buildstock_query.tools.upgrades_analyzer:Analyzing upgrade 4
# INFO:buildstock_query.tools.upgrades_analyzer:Analyzing upgrade 5
#      upgrade                               upgrade_name  option_num  \
# 0          1                                 Heat Pumps           1
# 1          1                                 Heat Pumps           2
# 2          1                                 Heat Pumps           3
# 3          1                                 Heat Pumps           4
# 4          1                                 Heat Pumps           5
# ..       ...                                        ...         ...
# 178        5  Heat Pump and PHIUS Envelope Improvements          57
# 179        5  Heat Pump and PHIUS Envelope Improvements          58
# 180        5  Heat Pump and PHIUS Envelope Improvements          59
# 181        5  Heat Pump and PHIUS Envelope Improvements          60
# 182        5  Heat Pump and PHIUS Envelope Improvements          -1
#
#                                                 option  applicable_to  \
# 0     HVAC Heating Efficiency|ASHP, SEER 26.1, 11 HSPF          29300
# 1    HVAC Heating Efficiency|MSHP, SEER 33.1, 13.5 ...          20369
# 2                    HVAC Cooling Efficiency|Heat Pump          49669
# 3    HVAC Cooling Partial Space Conditioning|100% C...          50000
# 4                          HVAC Has Shared System|None          50000
# ..                                                 ...            ...
# 178                             Ducts|10% Leakage, R-8            799
# 179                             Ducts|10% Leakage, R-8          12479
# 180                             Ducts|10% Leakage, R-8           1390
# 181                             Ducts|10% Leakage, R-8           6897
# 182                                                All          50000
#
#      applicable_percent                               applicable_buildings
# 0                  58.6  {35184, 25510, 18796, 20678, 47286, 30233, 461...
# 1                  40.7  {11582, 9608, 4977, 38250, 10205, 20918, 4481,...
# 2                  99.3  {35184, 25510, 11582, 18796, 20678, 47286, 960...
# 3                 100.0  {35184, 25510, 11582, 18796, 20678, 47286, 960...
# 4                 100.0  {35184, 25510, 11582, 18796, 20678, 47286, 960...
# ..                  ...                                                ...
# 178                 1.6  {39439, 3544, 29185, 36953, 30481, 10757, 3199...
# 179                25.0  {40875, 45919, 47755, 36808, 15864, 15196, 815...
# 180                 2.8  {15023, 30029, 40641, 3648, 4195, 20888, 12824...
# 181                13.8  {35184, 46854, 16067, 44106, 26391, 36967, 177...
# 182               100.0  {35184, 25510, 11582, 18796, 20678, 47286, 960...
#
# [183 rows x 7 columns]

# %% [markdown]
# ### Create upgraded buildstock

# %%
upg = 1
df_bsl = ua.buildstock_df_original.set_index("Building")
df_upg = ua.get_upgraded_buildstock(upg).set_index("Building")

# sometimes it's easier to QC by comparing upgraded buildstock with baseline buildstock
print(f"Difference between upg {upg} buildstock and baseline : ")
df_diff = df_bsl.compare(df_upg, result_names=("baseline", "upgrade"))
df_diff
# Out:
# INFO:buildstock_query.tools.upgrades_analyzer:Analyzing upgrade 1
# INFO:buildstock_query.tools.upgrades_analyzer: * Upgraded buildstock for upgrade 1 : Heat Pumps
# INFO:buildstock_query.tools.upgrades_analyzer:   Upgrade package has 9 options and was applied to 50000 / 50000 dwelling units ( 100.0 % )
# WARNING:buildstock_query.tools.upgrades_analyzer:Relative to baseline buildstock, upgraded buildstock has 7 fewer rows of difference than reported. This is okay, but indicates that some parameters are being upgraded to the same incumbent option (e.g., LEDs to LEDs). Check that this is intentional.
# Difference between upg 1 buildstock and baseline :
#          Heating Fuel              HVAC Has Shared System          \
#              baseline      upgrade               baseline upgrade
# Building
# 1         Natural Gas  Electricity                    NaN     NaN
# 2         Natural Gas  Electricity                    NaN     NaN
# 3                None  Electricity                    NaN     NaN
# 4                 NaN          NaN           Heating Only    None
# 5                 NaN          NaN                    NaN     NaN
# ...               ...          ...                    ...     ...
# 49996     Natural Gas  Electricity                    NaN     NaN
# 49997     Natural Gas  Electricity                    NaN     NaN
# 49998     Natural Gas  Electricity                    NaN     NaN
# 49999             NaN          NaN                    NaN     NaN
# 50000     Natural Gas  Electricity                    NaN     NaN
#
#                              HVAC Shared Efficiencies          \
#                                              baseline upgrade
# Building
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3                                                 NaN     NaN
# 4         Boiler Baseboards Heating Only, Electricity    None
# 5                                                 NaN     NaN
# ...                                               ...     ...
# 49996                                             NaN     NaN
# 49997                                             NaN     NaN
# 49998                                             NaN     NaN
# 49999                                             NaN     NaN
# 50000                                             NaN     NaN
#
#                     HVAC Heating Efficiency                              \
#                                    baseline                     upgrade
# Building
# 1         Fuel Wall/Floor Furnace, 68% AFUE  MSHP, SEER 33.1, 13.5 HSPF
# 2                    Fuel Furnace, 80% AFUE    ASHP, SEER 26.1, 11 HSPF
# 3                                      None  MSHP, SEER 33.1, 13.5 HSPF
# 4                            Shared Heating  MSHP, SEER 33.1, 13.5 HSPF
# 5               Electric Furnace, 100% AFUE    ASHP, SEER 26.1, 11 HSPF
# ...                                     ...                         ...
# 49996                Fuel Furnace, 80% AFUE    ASHP, SEER 26.1, 11 HSPF
# 49997                 Fuel Boiler, 80% AFUE  MSHP, SEER 33.1, 13.5 HSPF
# 49998              Fuel Furnace, 92.5% AFUE    ASHP, SEER 26.1, 11 HSPF
# 49999           Electric Furnace, 100% AFUE    ASHP, SEER 26.1, 11 HSPF
# 50000                 Fuel Boiler, 80% AFUE  MSHP, SEER 33.1, 13.5 HSPF
#
#          HVAC Cooling Efficiency             \
#                         baseline    upgrade
# Building
# 1               Room AC, EER 9.8  Heat Pump
# 2                    AC, SEER 13  Heat Pump
# 3               Room AC, EER 9.8  Heat Pump
# 4                           None  Heat Pump
# 5                    AC, SEER 13  Heat Pump
# ...                          ...        ...
# 49996                AC, SEER 10  Heat Pump
# 49997           Room AC, EER 9.8  Heat Pump
# 49998                AC, SEER 15  Heat Pump
# 49999                AC, SEER 15  Heat Pump
# 50000          Room AC, EER 10.7  Heat Pump
#
#          HVAC Cooling Partial Space Conditioning                    \
#                                         baseline           upgrade
# Building
# 1                                20% Conditioned  100% Conditioned
# 2                                            NaN               NaN
# 3                                            NaN               NaN
# 4                                           None  100% Conditioned
# 5                                            NaN               NaN
# ...                                          ...               ...
# 49996                                        NaN               NaN
# 49997                            20% Conditioned  100% Conditioned
# 49998                                        NaN               NaN
# 49999                                        NaN               NaN
# 50000                            20% Conditioned  100% Conditioned
#
#          HVAC Uses Cooling         Cooling Setpoint
#                   baseline upgrade         baseline upgrade
# Building
# 1                      NaN     NaN              82F     74F
# 2                      NaN     NaN              84F     74F
# 3                       No     Yes              Off     74F
# 4                       No     Yes              Off     74F
# 5                      NaN     NaN              80F     74F
# ...                    ...     ...              ...     ...
# 49996                   No     Yes              Off     74F
# 49997                   No     Yes              Off     74F
# 49998                  NaN     NaN              NaN     NaN
# 49999                  NaN     NaN              80F     74F
# 50000                   No     Yes              Off     74F
#
# [49993 rows x 16 columns]

# %%
report_df.drop(columns=['applicable_buildings']).to_csv("Upgrades_report.csv")

# %%
ua.save_detailed_report_all("detailed_report.txt")
# Out:
# INFO:buildstock_query.tools.upgrades_analyzer:Getting report for upgrade 1
# INFO:buildstock_query.tools.upgrades_analyzer:Getting report for upgrade 2
# INFO:buildstock_query.tools.upgrades_analyzer:Getting report for upgrade 3
# INFO:buildstock_query.tools.upgrades_analyzer:Getting report for upgrade 4
# INFO:buildstock_query.tools.upgrades_analyzer:Getting report for upgrade 5
