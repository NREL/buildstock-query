# %%
from buildstock_query import BuildStockQuery
import pandas as pd

# %%
# automatically reload the library if it changes
# %load_ext autoreload
# %autoreload 2

# %%
my_run = BuildStockQuery(db_name='euss-final',
                        table_name='euss_res_final_2018_550k_20220901',
                        workgroup='largeee',
                        buildstock_type='resstock')
# Out:
# INFO:buildstock_query.query_core:Loading euss_res_final_2018_550k_20220901 ...
# INFO:botocore.tokens:Loading cached SSO token for nrel-sso
# INFO:buildstock_query.query_core:13 queries cache read from None.
# INFO:buildstock_query.query_core:13 queries cache is updated.
# INFO:buildstock_query.main:Getting Success counts...
# INFO:buildstock_query.report_query:Checking integrity with ts_tables ...
# INFO:buildstock_query.query_core:No new queries to save.
#          fail  unapplicable  success     Sum  Applied %  no-chng  bad-chng  \
# upgrade
# 0        1084             0   548916  550000        0.0        0         0
# 1           1         17092   531823  548916       96.9     6097       949
# 10          0             0   548916  548916      100.0        1      5310
# 2           2         12117   536797  548916       97.8     6527       879
# 3           0           656   548260  548916       99.9      807     29954
# ...

# %%
res_df = my_run.get_results_csv_full()
res_df
# Out:
#              job_id          started_at        completed_at completed_status  \
# building_id
# 126379          280 2022-09-01 23:17:38 2022-09-01 23:18:07          Success
# 494504          460 2022-09-01 23:29:41 2022-09-01 23:30:34          Success
# 539777          384 2022-09-01 23:29:31 2022-09-01 23:30:00          Success
# 464849          464 2022-09-01 23:40:19 2022-09-01 23:41:20          Success
# 83789           370 2022-09-01 23:29:19 2022-09-01 23:30:29          Success
# ...             ...                 ...                 ...              ...
# 541636          345 2022-09-02 03:38:53 2022-09-02 03:39:24          Success
# 306039          507 2022-09-02 04:42:54 2022-09-02 04:43:20          Success
# 417922          272 2022-09-02 03:42:24 2022-09-02 03:43:27          Success
# 481235          424 2022-09-02 03:51:43 2022-09-02 03:52:04          Success
# 451352          510 2022-09-02 04:38:50 2022-09-02 04:39:14          Success
#
# ...

# %%
res_df = my_run.get_results_csv(restrict=[('build_existing_model.state', ['CO'])], get_query_only=True)
res_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/radhikar/Documents/buildstock_query/example_usage/basic_usage.ipynb Cell 5 in 2
#       <a href='vscode-notebook-cell:/Users/radhikar/Documents/buildstock_query/example_usage/basic_usage.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> res_df = my_run.get_results_csv(restrict=[('build_existing_model.state', ['CO'])], get_query_only=True)
# ----> <a href='vscode-notebook-cell:/Users/radhikar/Documents/buildstock_query/example_usage/basic_usage.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> res_df.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
res_df = my_run.get_results_csv(restrict=[('build_existing_model.state', ['CO'])], get_query_only=True)
res_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/radhikar/Documents/buildstock_query/example_usage/basic_usage.ipynb Cell 6 in 2
#       <a href='vscode-notebook-cell:/Users/radhikar/Documents/buildstock_query/example_usage/basic_usage.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> res_df = my_run.get_results_csv(restrict=[('build_existing_model.state', ['CO'])], get_query_only=True)
# ----> <a href='vscode-notebook-cell:/Users/radhikar/Documents/buildstock_query/example_usage/basic_usage.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> res_df.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
bsdf = my_run.get_buildstock_df()
bsdf
# Out:
#                                          ahs region applicable  \
# building_id
# 126379          CBSA Boston-Cambridge-Newton, MA-NH       True
# 494504          CBSA Boston-Cambridge-Newton, MA-NH       True
# 539777       CBSA Atlanta-Sandy Springs-Roswell, GA       True
# 464849                  Non-CBSA East South Central       True
# 83789                   Non-CBSA West North Central       True
# ...                                             ...        ...
# 541636                     Non-CBSA Middle Atlantic       True
# 306039                  Non-CBSA East North Central       True
# 417922                      Non-CBSA South Atlantic       True
# 481235             CBSA Seattle-Tacoma-Bellevue, WA       True
# 451352                     Non-CBSA Middle Atlantic       True
#
#             ashrae iecc climate zone 2004  \
# building_id
# 126379                                 5A
# 494504                                 5A
# 539777                                 3A
# ...

# %%
up1_csv = my_run.get_upgrades_csv_full(upgrade_id='2')
up1_csv
# Out:
# /Users/radhikar/Documents/buildstock_query/buildstock_query/main.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0, 'upgrade', upgrade_id)
#             upgrade  job_id          started_at        completed_at  \
# building_id
# 547402            2      37 2022-09-01 22:15:59 2022-09-01 22:17:13
# 231652            2     153 2022-09-01 23:04:39 2022-09-01 23:06:53
# 42486             2     330 2022-09-01 23:17:40 2022-09-01 23:18:24
# 328419            2     287 2022-09-01 23:17:36 2022-09-01 23:18:20
# 184799            2     566 2022-09-02 05:22:23 2022-09-02 05:23:25
# ...             ...     ...                 ...                 ...
# 282113            2     348 2022-09-02 03:39:12 2022-09-02 03:39:57
# ...
