# %%
from buildstock_query import BuildStockQuery
import pandas as pd
import os
os.environ['AWS_PROFILE'] = "nrel-aws-resbldg"
os.environ['AWS_DEFAULT_REGION'] = "us-west-2"
# Out:
# /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)

# %%
my_run = BuildStockQuery(db_name='gashpwh',
                        table_name='icf',
                        workgroup='gashpwh',
                        buildstock_type='resstock')
# Out:
# INFO:buildstock_query.query_core:Loading icf ...
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pyathena/common.py:279, in BaseCursor._get_table_metadata(self, table_name, catalog_name, schema_name, logging_)
#     278 try:
# --> 279     response = retry_api_call(
#     280         self._connection.client.get_table_metadata,
#     281         config=self._retry_config,
#     282         logger=_logger,
#     283         **request,
#     284     )
#     285 except Exception as e:
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pyathena/util.py:68, in retry_api_call(func, config, logger, *args, **kwargs)
#      52 retry = tenacity.Retrying(
#      53     retry=retry_if_exception(
#      54         lambda e: getattr(e, "response", {}).get("Error", {}).get("Code", None)
#    (...)
#      66     reraise=True,
#      67 )
# ---> 68 return retry(func, *args, **kwargs)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/client.py:963, in BaseClient._make_api_call(self, operation_name, api_params)
#     962     apply_request_checksum(request_dict)
# --> 963     http, parsed_response = self._make_request(
#     964         operation_model, request_dict, request_context
#     965     )
#     967 self.meta.events.emit(
#     968     'after-call.{service_id}.{operation_name}'.format(
#     969         service_id=service_id, operation_name=operation_name
#    (...)
#     974     context=request_context,
#     975 )
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/client.py:986, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#     985 try:
# --> 986     return self._endpoint.make_request(operation_model, request_dict)
#     987 except Exception as e:
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     114 logger.debug(
#     115     "Making request for %s with params: %s",
#     116     operation_model,
#     117     request_dict,
#     118 )
# --> 119 return self._send_request(request_dict, operation_model)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/endpoint.py:198, in Endpoint._send_request(self, request_dict, operation_model)
#     197 self._update_retries_context(context, attempts)
# --> 198 request = self.create_request(request_dict, operation_model)
#     199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/endpoint.py:134, in Endpoint.create_request(self, params, operation_model)
#     131     event_name = 'request-created.{service_id}.{op_name}'.format(
#     132         service_id=service_id, op_name=operation_model.name
#     133     )
# --> 134     self._event_emitter.emit(
#     135         event_name,
#     136         request=request,
#     137         operation_name=operation_model.name,
#     138     )
#     139 prepared_request = self.prepare_request(request)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     411 aliased_event_name = self._alias_event_name(event_name)
# --> 412 return self._emitter.emit(aliased_event_name, **kwargs)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     246 """
#     247 Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254          handlers.
#     255 """
# --> 256 return self._emit(event_name, kwargs)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     238 logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239 response = handler(**kwargs)
#     240 responses.append((handler, response))
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/signers.py:105, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     100 def handler(self, operation_name=None, request=None, **kwargs):
#     101     # This is typically hooked up to the "request-created" event
#     102     # from a client's event emitter.  When a new request is created
#     103     # this method is invoked to sign the request.
#     104     # Don't call this method directly.
# --> 105     return self.sign(operation_name, request)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/signers.py:189, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     187         raise e
# --> 189 auth.add_auth(request)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/botocore/auth.py:418, in SigV4Auth.add_auth(self, request)
#     417 if self.credentials is None:
# --> 418     raise NoCredentialsError()
#     419 datetime_now = datetime.datetime.utcnow()
#
# NoCredentialsError: Unable to locate credentials
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 my_run = BuildStockQuery(db_name='gashpwh',
#       2                         table_name='icf',
#       3                         workgroup='gashpwh',
#       4                         buildstock_type='resstock')
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:55, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      53 @wraps(_func)
#      54 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ---> 55     return vd.call(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:150, in ValidatedFunction.call(self, *args, **kwargs)
#     148 def call(self, *args: Any, **kwargs: Any) -> Any:
#     149     m = self.init_model_instance(*args, **kwargs)
# --> 150     return self.execute(m)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:222, in ValidatedFunction.execute(self, m)
#     220     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     221 else:
# --> 222     return self.raw_function(**d, **var_kwargs)
#
# File ~/Desktop/Scripting/NREL_Work/ICF/GemDev/buildstock-query/buildstock_query/main.py:75, in BuildStockQuery.__init__(self, workgroup, db_name, table_name, buildstock_type, timestamp_column_name, building_id_column_name, sample_weight, region_name, execution_history, skip_reports)
#      72 from buildstock_query.savings_query import BuildStockSavings
#      73 from buildstock_query.utility_query import BuildStockUtility
# ---> 75 super().__init__(params=self.run_params)
#      76 #: `buildstock_query.report_query.BuildStockReport` object to perform report queries
#      77 self.report: BuildStockReport = BuildStockReport(self)
#
# File ~/Desktop/Scripting/NREL_Work/ICF/GemDev/buildstock-query/buildstock_query/query_core.py:108, in QueryCore.__init__(self, params)
#     106 self.sample_weight = params.sample_weight
#     107 self.table_name = params.table_name
# --> 108 self._initialize_tables()
#     109 self._initialize_book_keeping(params.execution_history)
#     111 with contextlib.suppress(FileNotFoundError):
#
# File ~/Desktop/Scripting/NREL_Work/ICF/GemDev/buildstock-query/buildstock_query/query_core.py:154, in QueryCore._initialize_tables(self)
#     153 def _initialize_tables(self):
# --> 154     self.bs_table, self.ts_table, self.up_table = self._get_tables(self.table_name)
#     156     self.bs_bldgid_column = self.bs_table.c[self.building_id_column_name]
#     157     if self.ts_table is not None:
#
# File ~/Desktop/Scripting/NREL_Work/ICF/GemDev/buildstock-query/buildstock_query/query_core.py:226, in QueryCore._get_tables(self, table_name)
#     224 self._meta = sa.MetaData(bind=self._engine)
#     225 if isinstance(table_name, str):
# --> 226     baseline_table = self.get_table(f'{table_name}_baseline')
#     227     ts_table = self.get_table(f'{table_name}_timeseries', missing_ok=True)
#     228     upgrade_table = self.get_table(f'{table_name}_upgrades', missing_ok=True)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:55, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      53 @wraps(_func)
#      54 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ---> 55     return vd.call(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:150, in ValidatedFunction.call(self, *args, **kwargs)
#     148 def call(self, *args: Any, **kwargs: Any) -> Any:
#     149     m = self.init_model_instance(*args, **kwargs)
# --> 150     return self.execute(m)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:222, in ValidatedFunction.execute(self, m)
#     220     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     221 else:
# --> 222     return self.raw_function(**d, **var_kwargs)
#
# File ~/Desktop/Scripting/NREL_Work/ICF/GemDev/buildstock-query/buildstock_query/query_core.py:193, in QueryCore.get_table(self, table_name, missing_ok)
#     190     return table_name  # already a table
#     192 try:
# --> 193     return self._tables.setdefault(table_name, sa.Table(table_name, self._meta, autoload_with=self._engine))
#     194 except sa.exc.NoSuchTableError:  # type: ignore
#     195     if missing_ok:
#
# File <string>:2, in __new__(cls, *args, **kw)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:375, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     368     if m in kwargs:
#     369         _warn_with_version(
#     370             messages[m],
#     371             versions[m],
#     372             version_warnings[m],
#     373             stacklevel=3,
#     374         )
# --> 375 return fn(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/sql/schema.py:618, in Table.__new__(cls, *args, **kw)
#     616     return table
#     617 except Exception:
# --> 618     with util.safe_reraise():
#     619         metadata._remove_table(name, schema)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/sql/schema.py:614, in Table.__new__(cls, *args, **kw)
#     612 metadata._add_table(name, schema, table)
#     613 try:
# --> 614     table._init(name, metadata, *args, **kw)
#     615     table.dispatch.after_parent_attach(table, metadata)
#     616     return table
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/sql/schema.py:689, in Table._init(self, name, metadata, *args, **kwargs)
#     685 # load column definitions from the database if 'autoload' is defined
#     686 # we do it after the table is in the singleton dictionary to support
#     687 # circular foreign keys
#     688 if autoload:
# --> 689     self._autoload(
#     690         metadata,
#     691         autoload_with,
#     692         include_columns,
#     693         _extend_on=_extend_on,
#     694         resolve_fks=resolve_fks,
#     695     )
#     697 # initialize all the column, etc. objects.  done after reflection to
#     698 # allow user-overrides
#     700 self._init_items(
#     701     *args,
#     702     allow_replacements=extend_existing or keep_existing or autoload
#     703 )
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/sql/schema.py:724, in Table._autoload(self, metadata, autoload_with, include_columns, exclude_columns, resolve_fks, _extend_on)
#     722 insp = inspection.inspect(autoload_with)
#     723 with insp._inspection_context() as conn_insp:
# --> 724     conn_insp.reflect_table(
#     725         self,
#     726         include_columns,
#     727         exclude_columns,
#     728         resolve_fks,
#     729         _extend_on=_extend_on,
#     730     )
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/engine/reflection.py:757, in Inspector.reflect_table(self, table, include_columns, exclude_columns, resolve_fks, _extend_on)
#     750 reflection_options = dict(
#     751     (k, table.dialect_kwargs.get(k))
#     752     for k in dialect.reflection_options
#     753     if k in table.dialect_kwargs
#     754 )
#     756 # reflect table options, like mysql_engine
# --> 757 tbl_opts = self.get_table_options(
#     758     table_name, schema, **table.dialect_kwargs
#     759 )
#     760 if tbl_opts:
#     761     # add additional kwargs to the Table if the dialect
#     762     # returned them
#     763     table._validate_dialect_kwargs(tbl_opts)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/engine/reflection.py:398, in Inspector.get_table_options(self, table_name, schema, **kw)
#     396 if hasattr(self.dialect, "get_table_options"):
#     397     with self._operation_context() as conn:
# --> 398         return self.dialect.get_table_options(
#     399             conn, table_name, schema, info_cache=self.info_cache, **kw
#     400         )
#     401 return {}
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pyathena/sqlalchemy_athena.py:911, in AthenaDialect.get_table_options(self, connection, table_name, schema, **kw)
#     910 def get_table_options(self, connection, table_name, schema=None, **kw):
# --> 911     metadata = self._get_table(connection, table_name, schema=schema, **kw)
#     912     # TODO The metadata retrieved from the API does not seem to include bucketing information.
#     913     return {
#     914         "awsathena_location": metadata.location,
#     915         "awsathena_compression": metadata.compression,
#    (...)
#     919         "awsathena_tblproperties": HashableDict(metadata.table_properties),
#     920     }
#
# File <string>:2, in _get_table(self, connection, table_name, schema, **kw)
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/sqlalchemy/engine/reflection.py:55, in cache(fn, self, con, *args, **kw)
#      53 ret = info_cache.get(key)
#      54 if ret is None:
# ---> 55     ret = fn(self, con, *args, **kw)
#      56     info_cache[key] = ret
#      57 return ret
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pyathena/sqlalchemy_athena.py:867, in AthenaDialect._get_table(self, connection, table_name, schema, **kw)
#     865 with raw_connection.connection.cursor() as cursor:
#     866     try:
# --> 867         return cursor.get_table_metadata(table_name, schema_name=schema, logging_=False)
#     868     except pyathena.error.OperationalError as exc:
#     869         cause = exc.__cause__
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pyathena/common.py:299, in BaseCursor.get_table_metadata(self, table_name, catalog_name, schema_name, logging_)
#     292 def get_table_metadata(
#     293     self,
#     294     table_name: str,
#    (...)
#     297     logging_: bool = True,
#     298 ) -> AthenaTableMetadata:
# --> 299     return self._get_table_metadata(
#     300         table_name=table_name,
#     301         catalog_name=catalog_name,
#     302         schema_name=schema_name,
#     303         logging_=logging_,
#     304     )
#
# File /usr/local/anaconda3/envs/buildstock_query/lib/python3.10/site-packages/pyathena/common.py:288, in BaseCursor._get_table_metadata(self, table_name, catalog_name, schema_name, logging_)
#     286     if logging_:
#     287         _logger.exception("Failed to get table metadata.")
# --> 288     raise OperationalError(*e.args) from e
#     289 else:
#     290     return AthenaTableMetadata(response)
#
# OperationalError: Unable to locate credentials

# %%
import boto3
boto3.client('s3')

# %%
res_df = my_run.get_results_csv()

# %%
res_df = my_run.get_results_csv(restrict=[('build_existing_model.state', ['CO'])], get_query_only=False)
res_df

# %%
bsdf = my_run.get_buildstock_df()
bsdf

# %%
up1_csv = my_run.get_upgrades_csv(upgrade_id=2)
up1_csv
