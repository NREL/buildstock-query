# %%
from buildstock_query import BuildStockQuery
import pandas as pd
# Out:
# /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/pydantic/_internal/_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)

# %%
my_run = BuildStockQuery(db_name='euss-tests',
                        table_name='res_test_03_2018_10k_20220607',
                        workgroup='eulp',
                        buildstock_type='resstock')
# Out:
# INFO:buildstock_query.query_core:Loading res_test_03_2018_10k_20220607 ...
# ---------------------------------------------------------------------------
# ConfigParseError                          Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 my_run = BuildStockQuery(db_name='euss-tests',
#       2                         table_name='res_test_03_2018_10k_20220607',
#       3                         workgroup='eulp',
#       4                         buildstock_type='resstock')
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:55, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      53 @wraps(_func)
#      54 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ---> 55     return vd.call(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:150, in ValidatedFunction.call(self, *args, **kwargs)
#     148 def call(self, *args: Any, **kwargs: Any) -> Any:
#     149     m = self.init_model_instance(*args, **kwargs)
# --> 150     return self.execute(m)
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:222, in ValidatedFunction.execute(self, m)
#     220     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     221 else:
# --> 222     return self.raw_function(**d, **var_kwargs)
#
# File ~/Desktop/Scripting/NREL_Work/ICF/GemDev/buildstock-query/buildstock_query/main.py:75, in BuildStockQuery.__init__(self, workgroup, db_name, table_name, buildstock_type, timestamp_column_name, building_id_column_name, sample_weight, region_name, execution_history, skip_reports)
#      72 from buildstock_query.savings_query import BuildStockSavings
#      73 from buildstock_query.utility_query import BuildStockUtility
# ---> 75 super().__init__(params=self.run_params)
#      76 #: `buildstock_query.report_query.BuildStockReport` object to perform report queries
#      77 self.report: BuildStockReport = BuildStockReport(self)
#
# File ~/Desktop/Scripting/NREL_Work/ICF/GemDev/buildstock-query/buildstock_query/query_core.py:86, in QueryCore.__init__(self, params)
#      83 self._query_cache: dict[str, pd.DataFrame] = {}  # {"query": query_result_df} to cache queries
#      84 self._session_queries: set[str] = set()  # Set of all queries that is run in current session.
# ---> 86 self._aws_s3 = boto3.client('s3')
#      87 self._aws_athena = boto3.client('athena', region_name=params.region_name)
#      88 self._aws_glue = boto3.client('glue', region_name=params.region_name)
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/boto3/__init__.py:92, in client(*args, **kwargs)
#      86 def client(*args, **kwargs):
#      87     """
#      88     Create a low-level service client by name using the default session.
#      89
#      90     See :py:meth:`boto3.session.Session.client`.
#      91     """
# ---> 92     return _get_default_session().client(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/boto3/__init__.py:80, in _get_default_session()
#      73 """
#      74 Get the default session, creating one if needed.
#      75
#      76 :rtype: :py:class:`~boto3.session.Session`
#      77 :return: The default session
#      78 """
#      79 if DEFAULT_SESSION is None:
# ---> 80     setup_default_session()
#      81 _warn_deprecated_python()
#      83 return DEFAULT_SESSION
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/boto3/__init__.py:34, in setup_default_session(**kwargs)
#      28 """
#      29 Set up a default session, passing through any parameters to the session
#      30 constructor. There is no need to call this unless you wish to pass custom
#      31 parameters, because a default session will be created for you.
#      32 """
#      33 global DEFAULT_SESSION
# ---> 34 DEFAULT_SESSION = Session(**kwargs)
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/boto3/session.py:90, in Session.__init__(self, aws_access_key_id, aws_secret_access_key, aws_session_token, region_name, botocore_session, profile_name)
#      85     self._session.set_config_variable('region', region_name)
#      87 self.resource_factory = ResourceFactory(
#      88     self._session.get_component('event_emitter')
#      89 )
# ---> 90 self._setup_loader()
#      91 self._register_default_handlers()
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/boto3/session.py:131, in Session._setup_loader(self)
#     127 def _setup_loader(self):
#     128     """
#     129     Setup loader paths so that we can load resources.
#     130     """
# --> 131     self._loader = self._session.get_component('data_loader')
#     132     self._loader.search_paths.append(
#     133         os.path.join(os.path.dirname(__file__), 'data')
#     134     )
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/session.py:802, in Session.get_component(self, name)
#     800 def get_component(self, name):
#     801     try:
# --> 802         return self._components.get_component(name)
#     803     except ValueError:
#     804         if name in ['endpoint_resolver', 'exceptions_factory']:
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/session.py:1140, in ComponentLocator.get_component(self, name)
#    1138 if name in self._deferred:
#    1139     factory = self._deferred[name]
# -> 1140     self._components[name] = factory()
#    1141     # Only delete the component from the deferred dict after
#    1142     # successfully creating the object from the factory as well as
#    1143     # injecting the instantiated value into the _components dict.
#    1144     try:
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/session.py:199, in Session._register_data_loader.<locals>.<lambda>()
#     196 def _register_data_loader(self):
#     197     self._components.lazy_register_component(
#     198         'data_loader',
# --> 199         lambda: create_loader(self.get_config_variable('data_path')),
#     200     )
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/session.py:323, in Session.get_config_variable(self, logical_name, methods)
#     319 if methods is not None:
#     320     return self._get_config_variable_with_custom_methods(
#     321         logical_name, methods
#     322     )
# --> 323 return self.get_component('config_store').get_config_variable(
#     324     logical_name
#     325 )
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/configprovider.py:457, in ConfigValueStore.get_config_variable(self, logical_name)
#     455     return None
#     456 provider = self._mapping[logical_name]
# --> 457 return provider.provide()
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/configprovider.py:663, in ChainProvider.provide(self)
#     656 """Provide the value from the first provider to return non-None.
#     657
#     658 Each provider in the chain has its provide method called. The first
#     659 one in the chain to return a non-None value is the returned from the
#     660 ChainProvider. When no non-None value is found, None is returned.
#     661 """
#     662 for provider in self._providers:
# --> 663     value = provider.provide()
#     664     if value is not None:
#     665         return self._convert_type(value)
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/configprovider.py:753, in ScopedConfigProvider.provide(self)
#     751 def provide(self):
#     752     """Provide a value from a config file property."""
# --> 753     scoped_config = self._session.get_scoped_config()
#     754     if isinstance(self._config_var_name, tuple):
#     755         section_config = scoped_config.get(self._config_var_name[0])
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/session.py:412, in Session.get_scoped_config(self)
#     390 """
#     391 Returns the config values from the config file scoped to the current
#     392 profile.
#    (...)
#     409
#     410 """
#     411 profile_name = self.get_config_variable('profile')
# --> 412 profile_map = self._build_profile_map()
#     413 # If a profile is not explicitly set return the default
#     414 # profile config or an empty config dict if we don't have
#     415 # a default profile.
#     416 if profile_name is None:
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/session.py:308, in Session._build_profile_map(self)
#     303 def _build_profile_map(self):
#     304     # This will build the profile map if it has not been created,
#     305     # otherwise it will return the cached value.  The profile map
#     306     # is a list of profile names, to the config values for the profile.
#     307     if self._profile_map is None:
# --> 308         self._profile_map = self.full_config['profiles']
#     309     return self._profile_map
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/session.py:449, in Session.full_config(self)
#     442 try:
#     443     # Now we need to inject the profiles from the
#     444     # credentials file.  We don't actually need the values
#     445     # in the creds file, only the profile names so that we
#     446     # can validate the user is not referring to a nonexistent
#     447     # profile.
#     448     cred_file = self.get_config_variable('credentials_file')
# --> 449     cred_profiles = botocore.configloader.raw_config_parse(
#     450         cred_file
#     451     )
#     452     for profile in cred_profiles:
#     453         cred_vars = cred_profiles[profile]
#
# File /usr/local/anaconda3/envs/ICF_venv/lib/python3.10/site-packages/botocore/configloader.py:150, in raw_config_parse(config_filename, parse_subsections)
#     148     cp.read([path])
#     149 except (configparser.Error, UnicodeDecodeError) as e:
# --> 150     raise botocore.exceptions.ConfigParseError(
#     151         path=_unicode_path(path), error=e
#     152     ) from None
#     153 else:
#     154     for section in cp.sections():
#
# ConfigParseError: Unable to parse config file: /Users/kcu/.aws/credentials

# %%
res_df = my_run.get_results_csv()

# %%
res_df = my_run.get_results_csv(restrict=[('build_existing_model.state', ['CO'])], get_query_only=False)
res_df
# Out:
# INFO:buildstock_query.main:Making results_csv query ...
#              job_id          started_at        completed_at completed_status  \
# building_id
# 5279             31 2022-06-08 04:32:57 2022-06-08 04:33:29          Success
# 3354             45 2022-06-08 04:33:25 2022-06-08 04:33:53          Success
# 4945             13 2022-06-08 04:33:20 2022-06-08 04:33:47          Success
# 8853             41 2022-06-08 04:33:35 2022-06-08 04:33:58          Success
# 477              48 2022-06-08 04:35:28 2022-06-08 04:35:53          Success
# ...             ...                 ...                 ...              ...
# 2926             49 2022-06-08 05:21:51 2022-06-08 05:22:38          Success
# 4988              2 2022-06-08 05:19:01 2022-06-08 05:19:32          Success
# 3430              7 2022-06-08 05:19:45 2022-06-08 05:20:11          Success
# 8727             38 2022-06-08 05:22:43 2022-06-08 05:23:39          Success
# 722              36 2022-06-08 05:22:43 2022-06-08 05:23:21          Success
#
#              apply_upgrade.applicable  apply_upgrade.upgrade_name  \
# building_id
# 5279                             <NA>                        <NA>
# 3354                             <NA>                        <NA>
# 4945                             <NA>                        <NA>
# 8853                             <NA>                        <NA>
# 477                              <NA>                        <NA>
# ...                               ...                         ...
# 2926                             <NA>                        <NA>
# 4988                             <NA>                        <NA>
# 3430                             <NA>                        <NA>
# 8727                             <NA>                        <NA>
# 722                              <NA>                        <NA>
#
#             apply_upgrade.reference_scenario build_existing_model.ahs_region  \
# building_id
# 5279                                     NaN               Non-CBSA Mountain
# 3354                                     NaN               Non-CBSA Mountain
# 4945                                     NaN               Non-CBSA Mountain
# 8853                                     NaN               Non-CBSA Mountain
# 477                                      NaN               Non-CBSA Mountain
# ...                                      ...                             ...
# 2926                                     NaN               Non-CBSA Mountain
# 4988                                     NaN               Non-CBSA Mountain
# 3430                                     NaN               Non-CBSA Mountain
# 8727                                     NaN               Non-CBSA Mountain
# 722                                      NaN               Non-CBSA Mountain
#
#              build_existing_model.applicable  \
# building_id
# 5279                                    True
# 3354                                    True
# 4945                                    True
# 8853                                    True
# 477                                     True
# ...                                      ...
# 2926                                    True
# 4988                                    True
# 3430                                    True
# 8727                                    True
# 722                                     True
#
#             build_existing_model.ashrae_iecc_climate_zone_2004  ...  \
# building_id                                                     ...
# 5279                                                        5B  ...
# 3354                                                        5B  ...
# 4945                                                        5B  ...
# 8853                                                        5B  ...
# 477                                                         5B  ...
# ...                                                        ...  ...
# 2926                                                        7B  ...
# 4988                                                        5B  ...
# 3430                                                        5B  ...
# 8727                                                        7B  ...
# 722                                                         5B  ...
#
#             qoi_report.qoi_average_maximum_daily_use_overlap_kw  \
# building_id
# 5279                                                      1.90
# 3354                                                      2.94
# 4945                                                      1.47
# 8853                                                      2.37
# 477                                                       2.18
# ...                                                        ...
# 2926                                                      0.37
# 4988                                                      2.30
# 3430                                                      1.80
# 8727                                                      0.08
# 722                                                       1.30
#
#             qoi_report.qoi_average_minimum_daily_use_cooling_kw  \
# building_id
# 5279                                                      0.27
# 3354                                                      0.53
# 4945                                                      0.25
# 8853                                                      0.56
# 477                                                       0.33
# ...                                                        ...
# 2926                                                       NaN
# 4988                                                      0.26
# 3430                                                      0.29
# 8727                                                      0.04
# 722                                                       0.40
#
#             qoi_report.qoi_average_minimum_daily_use_heating_kw  \
# building_id
# 5279                                                      0.30
# 3354                                                      0.47
# 4945                                                      0.33
# 8853                                                      0.57
# 477                                                       0.40
# ...                                                        ...
# 2926                                                      0.16
# 4988                                                      0.28
# 3430                                                      0.35
# 8727                                                      0.25
# 722                                                       0.40
#
#             qoi_report.qoi_average_minimum_daily_use_overlap_kw  \
# building_id
# 5279                                                      0.26
# 3354                                                      0.44
# 4945                                                      0.26
# 8853                                                      0.56
# 477                                                       0.33
# ...                                                        ...
# 2926                                                      0.14
# 4988                                                      0.26
# 3430                                                      0.28
# 8727                                                      0.04
# 722                                                       0.40
#
#             qoi_report.qoi_average_of_top_ten_highest_peaks_timing_cooling_hour  \
# building_id
# 5279                                                     14.27
# 3354                                                     16.64
# 4945                                                     13.91
# 8853                                                     14.27
# 477                                                      14.27
# ...                                                        ...
# 2926                                                       NaN
# 4988                                                     14.36
# 3430                                                     13.09
# 8727                                                     20.00
# 722                                                      14.91
#
#             qoi_report.qoi_average_of_top_ten_highest_peaks_timing_heating_hour  \
# building_id
# 5279                                                     14.45
# 3354                                                     18.55
# 4945                                                     13.09
# 8853                                                     17.73
# 477                                                      18.55
# ...                                                        ...
# 2926                                                     15.55
# 4988                                                     15.18
# 3430                                                     16.64
# 8727                                                      7.00
# 722                                                      17.09
#
#             qoi_report.qoi_average_of_top_ten_highest_peaks_use_cooling_kw  \
# building_id
# 5279                                                      3.86
# 3354                                                      5.17
# 4945                                                      4.14
# 8853                                                      4.23
# 477                                                       5.12
# ...                                                        ...
# 2926                                                       NaN
# 4988                                                      5.71
# 3430                                                      4.22
# 8727                                                      0.09
# 722                                                       1.63
#
#             qoi_report.qoi_average_of_top_ten_highest_peaks_use_heating_kw  \
# building_id
# 5279                                                      3.44
# 3354                                                      4.53
# 4945                                                      4.61
# 8853                                                      5.06
# 477                                                       6.40
# ...                                                        ...
# 2926                                                      0.37
# 4988                                                      3.49
# 3430                                                      4.34
# 8727                                                      3.96
# 722                                                       2.19
#
#             qoi_report.qoi_peak_magnitude_timing_hour  \
# building_id
# 5279                                           4769.0
# 3354                                           3834.0
# 4945                                           3784.0
# 8853                                           8609.0
# 477                                            8225.0
# ...                                               ...
# 2926                                           4887.0
# 4988                                           4570.0
# 3430                                           3850.0
# 8727                                           1231.0
# 722                                            8610.0
#
#             qoi_report.qoi_peak_magnitude_use_kw
# building_id
# 5279                                        4.60
# 3354                                        5.60
# 4945                                        5.47
# 8853                                        5.37
# 477                                         6.79
# ...                                          ...
# 2926                                        0.60
# 4988                                        6.26
# 3430                                        5.09
# 8727                                        4.70
# 722                                         2.51
#
# [171 rows x 499 columns]

# %%
bsdf = my_run.get_buildstock_df()
bsdf
# Out:
#                                        ahs region applicable  \
# building_id
# 4021                  Non-CBSA West North Central       True
# 5017                     Non-CBSA Middle Atlantic       True
# 679                   Non-CBSA East North Central       True
# 6995                      Non-CBSA South Atlantic       True
# 3486                            Non-CBSA Mountain       True
# ...                                           ...        ...
# 3777                  Non-CBSA West South Central       True
# 2491                  Non-CBSA East South Central       True
# 2769                         Non-CBSA New England       True
# 4440                      Non-CBSA South Atlantic       True
# 468          CBSA Dallas-Fort Worth-Arlington, TX       True
#
#             ashrae iecc climate zone 2004  \
# building_id
# 4021                                   4A
# 5017                                   5A
# 679                                    5A
# 6995                                   4A
# 3486                                   5B
# ...                                   ...
# 3777                                   3A
# 2491                                   4A
# 2769                                   5A
# 4440                                   3A
# 468                                    3A
#
#             ashrae iecc climate zone 2004 2 a split bathroom spot vent hour  \
# building_id
# 4021                                             4A                  Hour13
# 5017                                             5A                  Hour19
# 679                                              5A                   Hour2
# 6995                                             4A                  Hour19
# 3486                                             5B                   Hour1
# ...                                             ...                     ...
# 3777                                             3A                   Hour0
# 2491                                             4A                   Hour3
# 2769                                             5A                   Hour8
# 4440                                             3A                   Hour5
# 468                                              3A                   Hour5
#
#             bedrooms building america climate zone cec climate zone  \
# building_id
# 4021               4                   Mixed-Humid             None
# 5017               4                          Cold             None
# 679                1                          Cold             None
# 6995               4                   Mixed-Humid             None
# 3486               1                          Cold             None
# ...              ...                           ...              ...
# 3777               3                   Mixed-Humid             None
# 2491               2                   Mixed-Humid             None
# 2769               3                          Cold             None
# 4440               3                   Mixed-Humid             None
# 468                3                     Hot-Humid             None
#
#                      ceiling fan     census division  ... vintage vintage acs  \
# building_id                                           ...
# 4021         Standard Efficiency  West North Central  ...   <1940       <1940
# 5017         Standard Efficiency     Middle Atlantic  ...   1950s     1940-59
# 679                         None  East North Central  ...   <1940       <1940
# 6995         Standard Efficiency      South Atlantic  ...   1980s     1980-99
# 3486                        None            Mountain  ...   1970s     1960-79
# ...                          ...                 ...  ...     ...         ...
# 3777                        None  West South Central  ...   1990s     1980-99
# 2491         Standard Efficiency  East South Central  ...   1990s     1980-99
# 2769         Standard Efficiency         New England  ...   1950s     1940-59
# 4440                        None      South Atlantic  ...   1970s     1960-79
# 468                         None  West South Central  ...   1990s     1980-99
#
#                 water heater efficiency water heater fuel  \
# building_id
# 4021               Natural Gas Standard       Natural Gas
# 5017               Natural Gas Standard       Natural Gas
# 679                Natural Gas Standard       Natural Gas
# 6995                  Electric Standard       Electricity
# 3486         Electric Heat Pump, 80 gal       Electricity
# ...                                 ...               ...
# 3777                   Electric Premium       Electricity
# 2491                  Electric Standard       Electricity
# 2769                  Electric Standard       Electricity
# 4440                  Electric Standard       Electricity
# 468                   Electric Standard       Electricity
#
#             water heater in unit    weather file city weather file latitude  \
# building_id
# 4021                         Yes     Coffeyville Muni                 37.09
# 5017                         Yes         Allegheny Co                 40.36
# 679                          Yes  Columbus Port Colum                 39.99
# 6995                         Yes  Baltimore Washingto                 39.17
# 3486                         Yes     Reno Cannon Intl                 39.48
# ...                          ...                  ...                   ...
# 3777                         Yes           Grider Fld                 34.18
# 2491                         Yes  Nashville Metropoli                 36.12
# 2769                         Yes  Providence Green St                 41.72
# 4440                         Yes       Monroe Airport                 35.02
# 468                          Yes       Arlington Muni                 32.66
#
#             weather file longitude     window areas  \
# building_id
# 4021                        -95.57  F12 B12 L12 R12
# 5017                        -79.92      F9 B9 L9 R9
# 679                         -82.88  F18 B18 L18 R18
# 6995                        -76.68  F12 B12 L12 R12
# 3486                       -119.77  F12 B12 L12 R12
# ...                            ...              ...
# 3777                        -91.94  F12 B12 L12 R12
# 2491                        -86.69  F12 B12 L12 R12
# 2769                        -71.43      F9 B9 L9 R9
# 4440                        -80.62  F18 B18 L18 R18
# 468                         -97.09  F30 B30 L30 R30
#
#                                                      windows
# building_id
# 4021                           Double, Clear, Non-metal, Air
# 5017          Single, Clear, Non-metal, Exterior Clear Storm
# 679                                 Single, Clear, Non-metal
# 6995                   Double, Low-E, Non-metal, Air, M-Gain
# 3486         Double, Clear, Metal, Air, Exterior Clear Storm
# ...                                                      ...
# 3777                               Double, Clear, Metal, Air
# 2491                   Double, Low-E, Non-metal, Air, M-Gain
# 2769                           Double, Clear, Non-metal, Air
# 4440                                    Single, Clear, Metal
# 468                                Double, Clear, Metal, Air
#
# [9989 rows x 153 columns]

# %%
up1_csv = my_run.get_upgrades_csv(upgrade_id=2)
up1_csv
# Out:
# INFO:buildstock_query.main:Making results_csv query for upgrade ...
#              job_id          started_at        completed_at completed_status  \
# building_id
# 1215             32 2022-06-08 04:31:44 2022-06-08 04:32:52          Success
# 6445             13 2022-06-08 04:31:42 2022-06-08 04:32:48          Success
# 7393             27 2022-06-08 04:31:42 2022-06-08 04:33:04          Success
# 1544             24 2022-06-08 04:31:43 2022-06-08 04:32:48          Success
# 5852             19 2022-06-08 04:31:43 2022-06-08 04:32:54          Success
# ...             ...                 ...                 ...              ...
# 6269             12 2022-06-08 05:23:20 2022-06-08 05:24:33          Success
# 276              14 2022-06-08 05:23:43 2022-06-08 05:24:20          Success
# 9762             29 2022-06-08 05:22:39 2022-06-08 05:23:30          Success
# 2151             18 2022-06-08 05:22:57 2022-06-08 05:23:57          Success
# 3544             48 2022-06-08 05:23:19 2022-06-08 05:24:04          Success
#
#             apply_upgrade.applicable apply_upgrade.upgrade_name  \
# building_id
# 1215                            True         Enhanced Enclosure
# 6445                            True         Enhanced Enclosure
# 7393                            True         Enhanced Enclosure
# 1544                            True         Enhanced Enclosure
# 5852                            True         Enhanced Enclosure
# ...                              ...                        ...
# 6269                            True         Enhanced Enclosure
# 276                             True         Enhanced Enclosure
# 9762                            True         Enhanced Enclosure
# 2151                            True         Enhanced Enclosure
# 3544                            True         Enhanced Enclosure
#
#             apply_upgrade.reference_scenario  \
# building_id
# 1215                                     NaN
# 6445                                     NaN
# 7393                                     NaN
# 1544                                     NaN
# 5852                                     NaN
# ...                                      ...
# 6269                                     NaN
# 276                                      NaN
# 9762                                     NaN
# 2151                                     NaN
# 3544                                     NaN
#
#             simulation_output_report.applicable  \
# building_id
# 1215                                       None
# 6445                                       None
# 7393                                       None
# 1544                                       None
# 5852                                       None
# ...                                         ...
# 6269                                       None
# 276                                        None
# 9762                                       None
# 2151                                       None
# 3544                                       None
#
#             report_simulation_output.add_timeseries_dst_column  \
# building_id
# 1215                                                      True
# 6445                                                      True
# 7393                                                      True
# 1544                                                      True
# 5852                                                      True
# ...                                                        ...
# 6269                                                      True
# 276                                                       True
# 9762                                                      True
# 2151                                                      True
# 3544                                                      True
#
#             report_simulation_output.add_timeseries_utc_column  ...  \
# building_id                                                     ...
# 1215                                                      True  ...
# 6445                                                      True  ...
# 7393                                                      True  ...
# 1544                                                      True  ...
# 5852                                                      True  ...
# ...                                                        ...  ...
# 6269                                                      True  ...
# 276                                                       True  ...
# 9762                                                      True  ...
# 2151                                                      True  ...
# 3544                                                      True  ...
#
#             qoi_report.qoi_average_minimum_daily_use_cooling_kw  \
# building_id
# 1215                                                      0.70
# 6445                                                      0.46
# 7393                                                      0.47
# 1544                                                      0.42
# 5852                                                      0.91
# ...                                                        ...
# 6269                                                      0.30
# 276                                                       0.61
# 9762                                                      0.83
# 2151                                                      1.34
# 3544                                                      0.58
#
#              qoi_report.qoi_average_minimum_daily_use_heating_kw  \
# building_id
# 1215                                                      0.72
# 6445                                                      0.30
# 7393                                                      0.30
# 1544                                                      0.30
# 5852                                                      1.31
# ...                                                        ...
# 6269                                                      0.07
# 276                                                       0.37
# 9762                                                      0.45
# 2151                                                      1.01
# 3544                                                      0.73
#
#              qoi_report.qoi_average_minimum_daily_use_overlap_kw  \
# building_id
# 1215                                                      0.68
# 6445                                                      0.30
# 7393                                                      0.25
# 1544                                                      0.31
# 5852                                                      0.27
# ...                                                        ...
# 6269                                                      0.10
# 276                                                       0.33
# 9762                                                      0.49
# 2151                                                      0.63
# 3544                                                      0.25
#
#              qoi_report.qoi_average_of_top_ten_highest_peaks_timing_cooling_hour  \
# building_id
# 1215                                                     12.27
# 6445                                                     16.55
# 7393                                                     15.09
# 1544                                                     13.27
# 5852                                                     14.91
# ...                                                        ...
# 6269                                                     17.18
# 276                                                      12.55
# 9762                                                     14.64
# 2151                                                     14.64
# 3544                                                     14.82
#
#              qoi_report.qoi_average_of_top_ten_highest_peaks_timing_heating_hour  \
# building_id
# 1215                                                     11.27
# 6445                                                     16.73
# 7393                                                     13.73
# 1544                                                     14.00
# 5852                                                      8.09
# ...                                                        ...
# 6269                                                      2.00
# 276                                                       8.45
# 9762                                                     15.27
# 2151                                                      9.82
# 3544                                                      9.45
#
#              qoi_report.qoi_average_of_top_ten_highest_peaks_use_cooling_kw  \
# building_id
# 1215                                                      5.05
# 6445                                                     14.66
# 7393                                                      3.65
# 1544                                                      5.34
# 5852                                                      3.87
# ...                                                        ...
# 6269                                                      1.14
# 276                                                       6.36
# 9762                                                      5.35
# 2151                                                      7.33
# 3544                                                      6.19
#
#              qoi_report.qoi_average_of_top_ten_highest_peaks_use_heating_kw  \
# building_id
# 1215                                                      5.06
# 6445                                                      5.38
# 7393                                                      1.55
# 1544                                                      6.16
# 5852                                                      5.11
# ...                                                        ...
# 6269                                                      4.15
# 276                                                       8.83
# 9762                                                      4.25
# 2151                                                      6.10
# 3544                                                      7.38
#
#              qoi_report.qoi_peak_magnitude_timing_hour  \
# building_id
# 1215                                            4809.0
# 6445                                            3873.0
# 7393                                            4817.0
# 1544                                            1519.0
# 5852                                             415.0
# ...                                                ...
# 6269                                             146.0
# 276                                             8490.0
# 9762                                            3974.0
# 2151                                            6375.0
# 3544                                             310.0
#
#              qoi_report.qoi_peak_magnitude_use_kw  upgrade
# building_id
# 1215                                         5.97        2
# 6445                                        23.41        2
# 7393                                         4.72        2
# 1544                                         7.21        2
# 5852                                         6.22        2
# ...                                           ...      ...
# 6269                                         5.36        2
# 276                                          9.93        2
# 9762                                         5.95        2
# 2151                                         8.97        2
# 3544                                         9.12        2
#
# [10000 rows x 347 columns]
